# %%
import pandas as pd
import numpy as np
import nltk
from collections import Counter
from nltk.corpus import stopwords
from sklearn.metrics import log_loss
from scipy.optimize import minimize
# import xgboost as xgb
import lightgbm as lgb
from sklearn.cross_validation import train_test_split
import multiprocessing
import difflib

import dask.dataframe as dd
import dask.bag as db
from dask.dataframe.utils import make_meta
from dask.multiprocessing import get

stops = set(stopwords.words("english"))
# Out:
# D:\soft\dev\anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train = pd.read_csv('./data/train.csv')#[:1000] #remove limit
test = pd.read_csv('./data/test.csv')#[:1000] #remove limit

# %%
def apply_parallel(sequence, func, partitions=4):
    bag = db.from_sequence(sequence, npartitions=partitions)
    res = bag.map(func).compute()
    return res

def get_words(question):
    words = {}
    for word in question.split():
        if word not in stops:
            words[word] = 1
    return words

# %%
def diff_ratios(st1, st2):
    seq = difflib.SequenceMatcher()
    seq.set_seqs(str1, str2)
    return seq.ratio()

def word_match_share(word_dicts):
    q1words, q2words = word_dicts
    if len(q1words) == 0 or len(q2words) == 0:
        return 0
    shared_words_in_q1 = [w for w in q1words.keys() if w in q2words]
    shared_words_in_q2 = [w for w in q2words.keys() if w in q1words]
    R = (len(shared_words_in_q1) + len(shared_words_in_q2)) / (len(q1words) + len(q2words))
    return R

def get_weight(count, eps=500, min_count=2):
    if count < min_count:
        return 0
    else:
        return 1. / (count + eps)

def tfidf_word_match_share(word_dicts):
    q1words, q2words = word_dicts
    if len(q1words) == 0 or len(q2words) == 0:
        return 0
    shared_weights = [weights.get(w, 0) for w in q1words.keys() if w in q2words] + [weights.get(w, 0) for w in q2words.keys() if w in q1words]
    total_weights = [weights.get(w, 0) for w in q1words] + [weights.get(w, 0) for w in q2words]
    R = np.sum(shared_weights) / np.sum(total_weights)
    return R

def get_unigrams(que):
    return [word for word in nltk.word_tokenize(que.lower()) if word not in stops]

def get_common_unigrams(row):
    return len(set(row["unigrams_ques1"]).intersection(set(row["unigrams_ques2"])))

def get_common_unigram_ratio(row):
    return float(row["zunigrams_common_count"]) / max(len( set(row["unigrams_ques1"]).union(set(row["unigrams_ques2"])) ),1)

def get_bigrams(que):
    return [i for i in nltk.ngrams(que, 2)]

def get_common_bigrams(row):
    return len( set(row["bigrams_ques1"]).intersection(set(row["bigrams_ques2"])) )

def get_common_bigram_ratio(row):
    return float(row["zbigrams_common_count"]) / max(len( set(row["bigrams_ques1"]).union(set(row["bigrams_ques2"])) ),1)

def get_features(train):
    print('== start get features')
    train['question1'] = train['question1'].astype(str)
    train['question2'] = train['question2'].astype(str)
    train['question1'] = train['question1'].str.lower()
    train['question2'] = train['question2'].str.lower()
    
    print('== receiving nouns')
    train['q1_nouns'] = apply_parallel(train['question1'], lambda x: [w for w, t in nltk.pos_tag(nltk.word_tokenize(x)) if t in ['N']]) # t[:1]
    train['q2_nouns'] = apply_parallel(train['question2'], lambda x: [w for w, t in nltk.pos_tag(nltk.word_tokenize(x)) if t in ['N']]) # t[:1]

    print('== receiving length')
    train['z_len1'] = train['question1'].map(len)
    train['z_len2'] = train['question2'].map(len)
    train['z_word_len1'] = train['question1'].map(lambda x: len(x.split()))
    train['z_word_len2'] = train['question2'].map(lambda x: len(x.split()))
    
    #train['z_noun_match'] = train.apply(lambda r: sum([1 for w in r.question1_nouns if w in r.question2_nouns]), axis=1)  #takes long
    #train['z_match_ratio'] = train.apply(lambda r: diff_ratios(r.question1, r.question2), axis=1)  #takes long

    word_dicts1 = apply_parallel(train['question1'], get_words)
    word_dicts2 = apply_parallel(train['question2'], get_words)
    word_dicts = list(zip(word_dicts1, word_dicts2))
#     del word_dicts1
#     del word_dicts2
    
    print('== receiving matches and ngrams')
    train['z_word_match'] = apply_parallel(word_dicts, word_match_share)    
    train['z_tfidf_word_match'] = apply_parallel(word_dicts, word_match_share)

    train['unigrams_ques1'] = apply_parallel(train['question1'], get_unigrams)
    train['unigrams_ques2'] = apply_parallel(train['question1'], get_unigrams)
    
    train['zunigrams_common_count'] = train.apply(get_common_unigrams, axis=1)
    train['zunigrams_common_ratio'] = train.apply(get_common_unigram_ratio, axis=1)
    train['bigrams_ques1'] = train['unigrams_ques1'].apply(get_bigrams)
    train['bigrams_ques2'] = train['unigrams_ques2'].apply(get_bigrams) 
    train['zbigrams_common_count'] = train.apply(get_common_bigrams, axis=1)
    train['zbigrams_common_ratio'] = train.apply(get_common_bigram_ratio, axis=1)
    print('== features received.')
    return train

# %%
train_qs = pd.Series(train['question1'].tolist() + train['question2'].tolist()).astype(str)
test_qs = pd.Series(test['question1'].tolist() + test['question2'].tolist()).astype(str)
words = (" ".join(train_qs)).lower().split() + (" ".join(test_qs)).lower().split()
counts = Counter(words)
weights = {word: get_weight(count) for word, count in counts.items()}

# %%
# %%time
train = get_features(train)
train = train.fillna(-1)
# Out:
# Wall time: 8min 40s

# %%
train.to_csv('feat_train.csv', index=False)

# %%
col = [c for c in train.columns if c[:1]=='z']

pos_train = train[train['is_duplicate'] == 1]
neg_train = train[train['is_duplicate'] == 0]
p = 0.165
scale = ((len(pos_train) / (len(pos_train) + len(neg_train))) / p) - 1
while scale > 1:
    neg_train = pd.concat([neg_train, neg_train])
    scale -=1
neg_train = pd.concat([neg_train, neg_train[:int(scale * len(neg_train))]])
train = pd.concat([pos_train, neg_train])

x_train, x_valid, y_train, y_valid = train_test_split(train[col], train['is_duplicate'], test_size=0.2, random_state=0)

# %%
lgb_train = lgb.Dataset(x_train, y_train)
lgb_valid = lgb.Dataset(x_valid, y_valid, reference=lgb_train)

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'binary_logloss',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}


print('Start training...')
gbm = lgb.train(params,
                lgb_train,
                num_boost_round=5000,
                valid_sets=lgb_valid,
                early_stopping_rounds=5)
print('Done')
# Out:
# Start training...
# [1]	valid_0's binary_logloss: 0.668217
# Train until valid scores didn't improve in 5 rounds.
# [2]	valid_0's binary_logloss: 0.645644
# [3]	valid_0's binary_logloss: 0.625138
# [4]	valid_0's binary_logloss: 0.60644
# [5]	valid_0's binary_logloss: 0.589337
# [6]	valid_0's binary_logloss: 0.573636
# [7]	valid_0's binary_logloss: 0.559222
# [8]	valid_0's binary_logloss: 0.545941
# [9]	valid_0's binary_logloss: 0.533683
# [10]	valid_0's binary_logloss: 0.522337
# [11]	valid_0's binary_logloss: 0.511823
# [12]	valid_0's binary_logloss: 0.502078
# [13]	valid_0's binary_logloss: 0.493031
# [14]	valid_0's binary_logloss: 0.484614
# [15]	valid_0's binary_logloss: 0.476786
# [16]	valid_0's binary_logloss: 0.469499
# [17]	valid_0's binary_logloss: 0.462679
# [18]	valid_0's binary_logloss: 0.456311
# [19]	valid_0's binary_logloss: 0.450359
# [20]	valid_0's binary_logloss: 0.444799
# [21]	valid_0's binary_logloss: 0.439576
# [22]	valid_0's binary_logloss: 0.434679
# [23]	valid_0's binary_logloss: 0.430105
# [24]	valid_0's binary_logloss: 0.425813
# [25]	valid_0's binary_logloss: 0.421791
# [26]	valid_0's binary_logloss: 0.418002
# [27]	valid_0's binary_logloss: 0.414437
# [28]	valid_0's binary_logloss: 0.411093
# [29]	valid_0's binary_logloss: 0.407951
# [30]	valid_0's binary_logloss: 0.404998
# [31]	valid_0's binary_logloss: 0.402205
# [32]	valid_0's binary_logloss: 0.399562
# [33]	valid_0's binary_logloss: 0.397099
# [34]	valid_0's binary_logloss: 0.394775
# [35]	valid_0's binary_logloss: 0.39258
# [36]	valid_0's binary_logloss: 0.390499
# [37]	valid_0's binary_logloss: 0.388543
# [38]	valid_0's binary_logloss: 0.386683
# [39]	valid_0's binary_logloss: 0.38496
# [40]	valid_0's binary_logloss: 0.383315
# [41]	valid_0's binary_logloss: 0.381749
# [42]	valid_0's binary_logloss: 0.380257
# [43]	valid_0's binary_logloss: 0.378842
# [44]	valid_0's binary_logloss: 0.377535
# [45]	valid_0's binary_logloss: 0.376284
# [46]	valid_0's binary_logloss: 0.375115
# [47]	valid_0's binary_logloss: 0.374009
# [48]	valid_0's binary_logloss: 0.37297
# [49]	valid_0's binary_logloss: 0.371962
# [50]	valid_0's binary_logloss: 0.371021
# [51]	valid_0's binary_logloss: 0.370147
# [52]	valid_0's binary_logloss: 0.369303
# [53]	valid_0's binary_logloss: 0.368518
# [54]	valid_0's binary_logloss: 0.367756
# [55]	valid_0's binary_logloss: 0.36705
# [56]	valid_0's binary_logloss: 0.366362
# [57]	valid_0's binary_logloss: 0.365725
# [58]	valid_0's binary_logloss: 0.36512
# [59]	valid_0's binary_logloss: 0.364548
# [60]	valid_0's binary_logloss: 0.364006
# [61]	valid_0's binary_logloss: 0.363487
# [62]	valid_0's binary_logloss: 0.362995
# [63]	valid_0's binary_logloss: 0.362551
# [64]	valid_0's binary_logloss: 0.36212
# [65]	valid_0's binary_logloss: 0.361709
# [66]	valid_0's binary_logloss: 0.361291
# [67]	valid_0's binary_logloss: 0.360884
# [68]	valid_0's binary_logloss: 0.360507
# [69]	valid_0's binary_logloss: 0.360158
# [70]	valid_0's binary_logloss: 0.359821
# [71]	valid_0's binary_logloss: 0.359513
# [72]	valid_0's binary_logloss: 0.35921
# [73]	valid_0's binary_logloss: 0.358937
# [74]	valid_0's binary_logloss: 0.358667
# [75]	valid_0's binary_logloss: 0.358408
# [76]	valid_0's binary_logloss: 0.358146
# [77]	valid_0's binary_logloss: 0.357913
# [78]	valid_0's binary_logloss: 0.357695
# [79]	valid_0's binary_logloss: 0.357488
# [80]	valid_0's binary_logloss: 0.357304
# [81]	valid_0's binary_logloss: 0.357111
# [82]	valid_0's binary_logloss: 0.356912
# [83]	valid_0's binary_logloss: 0.35675
# [84]	valid_0's binary_logloss: 0.356583
# [85]	valid_0's binary_logloss: 0.356421
# [86]	valid_0's binary_logloss: 0.356279
# [87]	valid_0's binary_logloss: 0.356139
# [88]	valid_0's binary_logloss: 0.355991
# [89]	valid_0's binary_logloss: 0.355859
# [90]	valid_0's binary_logloss: 0.355745
# [91]	valid_0's binary_logloss: 0.355623
# [92]	valid_0's binary_logloss: 0.355513
# [93]	valid_0's binary_logloss: 0.355417
# [94]	valid_0's binary_logloss: 0.35531
# [95]	valid_0's binary_logloss: 0.355209
# [96]	valid_0's binary_logloss: 0.355092
# [97]	valid_0's binary_logloss: 0.355
# [98]	valid_0's binary_logloss: 0.35491
# [99]	valid_0's binary_logloss: 0.354828
# [100]	valid_0's binary_logloss: 0.354728
# [101]	valid_0's binary_logloss: 0.354642
# [102]	valid_0's binary_logloss: 0.354531
# [103]	valid_0's binary_logloss: 0.354442
# [104]	valid_0's binary_logloss: 0.354356
# [105]	valid_0's binary_logloss: 0.354272
# [106]	valid_0's binary_logloss: 0.354201
# [107]	valid_0's binary_logloss: 0.354134
# [108]	valid_0's binary_logloss: 0.354047
# [109]	valid_0's binary_logloss: 0.353961
# [110]	valid_0's binary_logloss: 0.353909
# [111]	valid_0's binary_logloss: 0.353817
# [112]	valid_0's binary_logloss: 0.353742
# [113]	valid_0's binary_logloss: 0.353676
# [114]	valid_0's binary_logloss: 0.353632
# [115]	valid_0's binary_logloss: 0.35356
# [116]	valid_0's binary_logloss: 0.3535
# [117]	valid_0's binary_logloss: 0.353459
# [118]	valid_0's binary_logloss: 0.353422
# [119]	valid_0's binary_logloss: 0.353384
# [120]	valid_0's binary_logloss: 0.353344
# [121]	valid_0's binary_logloss: 0.353261
# [122]	valid_0's binary_logloss: 0.353209
# [123]	valid_0's binary_logloss: 0.353133
# [124]	valid_0's binary_logloss: 0.353089
# [125]	valid_0's binary_logloss: 0.353046
# [126]	valid_0's binary_logloss: 0.35301
# [127]	valid_0's binary_logloss: 0.352975
# [128]	valid_0's binary_logloss: 0.352927
# [129]	valid_0's binary_logloss: 0.352887
# [130]	valid_0's binary_logloss: 0.352858
# [131]	valid_0's binary_logloss: 0.352817
# [132]	valid_0's binary_logloss: 0.352788
# [133]	valid_0's binary_logloss: 0.352747
# [134]	valid_0's binary_logloss: 0.352715
# [135]	valid_0's binary_logloss: 0.352694
# [136]	valid_0's binary_logloss: 0.352645
# [137]	valid_0's binary_logloss: 0.352594
# [138]	valid_0's binary_logloss: 0.352559
# [139]	valid_0's binary_logloss: 0.352521
# [140]	valid_0's binary_logloss: 0.352486
# [141]	valid_0's binary_logloss: 0.35245
# [142]	valid_0's binary_logloss: 0.352419
# [143]	valid_0's binary_logloss: 0.352386
# [144]	valid_0's binary_logloss: 0.352343
# [145]	valid_0's binary_logloss: 0.352319
# [146]	valid_0's binary_logloss: 0.35228
# [147]	valid_0's binary_logloss: 0.352243
# [148]	valid_0's binary_logloss: 0.352204
# [149]	valid_0's binary_logloss: 0.352173
# [150]	valid_0's binary_logloss: 0.352144
# [151]	valid_0's binary_logloss: 0.352124
# [152]	valid_0's binary_logloss: 0.352096
# [153]	valid_0's binary_logloss: 0.352075
# [154]	valid_0's binary_logloss: 0.352027
# [155]	valid_0's binary_logloss: 0.351988
# [156]	valid_0's binary_logloss: 0.351975
# [157]	valid_0's binary_logloss: 0.351937
# [158]	valid_0's binary_logloss: 0.351925
# [159]	valid_0's binary_logloss: 0.35191
# [160]	valid_0's binary_logloss: 0.351897
# [161]	valid_0's binary_logloss: 0.351853
# [162]	valid_0's binary_logloss: 0.351822
# [163]	valid_0's binary_logloss: 0.351805
# [164]	valid_0's binary_logloss: 0.351782
# [165]	valid_0's binary_logloss: 0.351737
# [166]	valid_0's binary_logloss: 0.351692
# [167]	valid_0's binary_logloss: 0.351652
# [168]	valid_0's binary_logloss: 0.351616
# [169]	valid_0's binary_logloss: 0.351586
# [170]	valid_0's binary_logloss: 0.351554
# [171]	valid_0's binary_logloss: 0.351529
# [172]	valid_0's binary_logloss: 0.351497
# [173]	valid_0's binary_logloss: 0.351449
# [174]	valid_0's binary_logloss: 0.351411
# [175]	valid_0's binary_logloss: 0.351381
# [176]	valid_0's binary_logloss: 0.351343
# [177]	valid_0's binary_logloss: 0.351311
# [178]	valid_0's binary_logloss: 0.351275
# [179]	valid_0's binary_logloss: 0.351249
# [180]	valid_0's binary_logloss: 0.351225
# [181]	valid_0's binary_logloss: 0.351187
# [182]	valid_0's binary_logloss: 0.351164
# [183]	valid_0's binary_logloss: 0.35114
# [184]	valid_0's binary_logloss: 0.351121
# [185]	valid_0's binary_logloss: 0.351112
# [186]	valid_0's binary_logloss: 0.351087
# [187]	valid_0's binary_logloss: 0.351043
# [188]	valid_0's binary_logloss: 0.351014
# [189]	valid_0's binary_logloss: 0.350997
# [190]	valid_0's binary_logloss: 0.350971
# [191]	valid_0's binary_logloss: 0.350956
# [192]	valid_0's binary_logloss: 0.350939
# [193]	valid_0's binary_logloss: 0.350923
# [194]	valid_0's binary_logloss: 0.350906
# [195]	valid_0's binary_logloss: 0.350888
# [196]	valid_0's binary_logloss: 0.350876
# [197]	valid_0's binary_logloss: 0.350864
# [198]	valid_0's binary_logloss: 0.350849
# [199]	valid_0's binary_logloss: 0.35084
# [200]	valid_0's binary_logloss: 0.350828
# [201]	valid_0's binary_logloss: 0.350812
# [202]	valid_0's binary_logloss: 0.350797
# [203]	valid_0's binary_logloss: 0.350782
# [204]	valid_0's binary_logloss: 0.350761
# [205]	valid_0's binary_logloss: 0.350749
# [206]	valid_0's binary_logloss: 0.350713
# [207]	valid_0's binary_logloss: 0.350695
# [208]	valid_0's binary_logloss: 0.350674
# [209]	valid_0's binary_logloss: 0.350645
# [210]	valid_0's binary_logloss: 0.350629
# [211]	valid_0's binary_logloss: 0.350609
# [212]	valid_0's binary_logloss: 0.350594
# [213]	valid_0's binary_logloss: 0.350574
# [214]	valid_0's binary_logloss: 0.350543
# [215]	valid_0's binary_logloss: 0.350531
# [216]	valid_0's binary_logloss: 0.350505
# [217]	valid_0's binary_logloss: 0.350465
# [218]	valid_0's binary_logloss: 0.350439
# [219]	valid_0's binary_logloss: 0.350414
# [220]	valid_0's binary_logloss: 0.350397
# [221]	valid_0's binary_logloss: 0.350373
# [222]	valid_0's binary_logloss: 0.350365
# [223]	valid_0's binary_logloss: 0.35035
# [224]	valid_0's binary_logloss: 0.350335
# [225]	valid_0's binary_logloss: 0.350318
# [226]	valid_0's binary_logloss: 0.350298
# [227]	valid_0's binary_logloss: 0.350266
# [228]	valid_0's binary_logloss: 0.350244
# [229]	valid_0's binary_logloss: 0.350233
# [230]	valid_0's binary_logloss: 0.350202
# [231]	valid_0's binary_logloss: 0.350182
# [232]	valid_0's binary_logloss: 0.350155
# [233]	valid_0's binary_logloss: 0.350136
# [234]	valid_0's binary_logloss: 0.350111
# [235]	valid_0's binary_logloss: 0.350092
# [236]	valid_0's binary_logloss: 0.350078
# [237]	valid_0's binary_logloss: 0.350066
# [238]	valid_0's binary_logloss: 0.350057
# [239]	valid_0's binary_logloss: 0.350046
# [240]	valid_0's binary_logloss: 0.350035
# [241]	valid_0's binary_logloss: 0.350014
# [242]	valid_0's binary_logloss: 0.349993
# [243]	valid_0's binary_logloss: 0.349975
# [244]	valid_0's binary_logloss: 0.349953
# [245]	valid_0's binary_logloss: 0.349931
# [246]	valid_0's binary_logloss: 0.349918
# [247]	valid_0's binary_logloss: 0.349901
# [248]	valid_0's binary_logloss: 0.34989
# [249]	valid_0's binary_logloss: 0.349877
# [250]	valid_0's binary_logloss: 0.349862
# [251]	valid_0's binary_logloss: 0.349851
# [252]	valid_0's binary_logloss: 0.349841
# [253]	valid_0's binary_logloss: 0.349835
# [254]	valid_0's binary_logloss: 0.34983
# [255]	valid_0's binary_logloss: 0.349822
# [256]	valid_0's binary_logloss: 0.349803
# [257]	valid_0's binary_logloss: 0.349781
# [258]	valid_0's binary_logloss: 0.349757
# [259]	valid_0's binary_logloss: 0.349746
# [260]	valid_0's binary_logloss: 0.349732
# [261]	valid_0's binary_logloss: 0.349719
# [262]	valid_0's binary_logloss: 0.34971
# [263]	valid_0's binary_logloss: 0.349705
# [264]	valid_0's binary_logloss: 0.349699
# [265]	valid_0's binary_logloss: 0.349696
# [266]	valid_0's binary_logloss: 0.349682
# [267]	valid_0's binary_logloss: 0.349672
# [268]	valid_0's binary_logloss: 0.349664
# [269]	valid_0's binary_logloss: 0.349644
# [270]	valid_0's binary_logloss: 0.349626
# [271]	valid_0's binary_logloss: 0.349611
# [272]	valid_0's binary_logloss: 0.349601
# [273]	valid_0's binary_logloss: 0.349589
# [274]	valid_0's binary_logloss: 0.349574
# [275]	valid_0's binary_logloss: 0.349564
# [276]	valid_0's binary_logloss: 0.349551
# [277]	valid_0's binary_logloss: 0.349541
# [278]	valid_0's binary_logloss: 0.349533
# [279]	valid_0's binary_logloss: 0.349526
# [280]	valid_0's binary_logloss: 0.349515
# [281]	valid_0's binary_logloss: 0.349499
# [282]	valid_0's binary_logloss: 0.349483
# [283]	valid_0's binary_logloss: 0.349477
# [284]	valid_0's binary_logloss: 0.349452
# [285]	valid_0's binary_logloss: 0.349438
# [286]	valid_0's binary_logloss: 0.349414
# [287]	valid_0's binary_logloss: 0.349395
# [288]	valid_0's binary_logloss: 0.349378
# [289]	valid_0's binary_logloss: 0.349354
# [290]	valid_0's binary_logloss: 0.349343
# [291]	valid_0's binary_logloss: 0.349323
# [292]	valid_0's binary_logloss: 0.349315
# [293]	valid_0's binary_logloss: 0.349289
# [294]	valid_0's binary_logloss: 0.349274
# [295]	valid_0's binary_logloss: 0.349259
# [296]	valid_0's binary_logloss: 0.349236
# [297]	valid_0's binary_logloss: 0.349228
# [298]	valid_0's binary_logloss: 0.349216
# [299]	valid_0's binary_logloss: 0.349204
# [300]	valid_0's binary_logloss: 0.349188
# [301]	valid_0's binary_logloss: 0.349181
# [302]	valid_0's binary_logloss: 0.349173
# [303]	valid_0's binary_logloss: 0.349169
# [304]	valid_0's binary_logloss: 0.349145
# [305]	valid_0's binary_logloss: 0.349135
# [306]	valid_0's binary_logloss: 0.34912
# [307]	valid_0's binary_logloss: 0.349113
# [308]	valid_0's binary_logloss: 0.349096
# [309]	valid_0's binary_logloss: 0.349077
# [310]	valid_0's binary_logloss: 0.349067
# [311]	valid_0's binary_logloss: 0.34906
# [312]	valid_0's binary_logloss: 0.349051
# [313]	valid_0's binary_logloss: 0.349046
# [314]	valid_0's binary_logloss: 0.349044
# [315]	valid_0's binary_logloss: 0.349028
# [316]	valid_0's binary_logloss: 0.349006
# [317]	valid_0's binary_logloss: 0.348996
# [318]	valid_0's binary_logloss: 0.348986
# [319]	valid_0's binary_logloss: 0.348968
# [320]	valid_0's binary_logloss: 0.348946
# [321]	valid_0's binary_logloss: 0.348932
# [322]	valid_0's binary_logloss: 0.348923
# [323]	valid_0's binary_logloss: 0.348913
# [324]	valid_0's binary_logloss: 0.348898
# [325]	valid_0's binary_logloss: 0.348887
# [326]	valid_0's binary_logloss: 0.348871
# [327]	valid_0's binary_logloss: 0.348854
# [328]	valid_0's binary_logloss: 0.348847
# [329]	valid_0's binary_logloss: 0.348836
# [330]	valid_0's binary_logloss: 0.348814
# [331]	valid_0's binary_logloss: 0.348796
# [332]	valid_0's binary_logloss: 0.34878
# [333]	valid_0's binary_logloss: 0.34876
# [334]	valid_0's binary_logloss: 0.348742
# [335]	valid_0's binary_logloss: 0.34873
# [336]	valid_0's binary_logloss: 0.348716
# [337]	valid_0's binary_logloss: 0.348703
# [338]	valid_0's binary_logloss: 0.348688
# [339]	valid_0's binary_logloss: 0.348681
# [340]	valid_0's binary_logloss: 0.348671
# [341]	valid_0's binary_logloss: 0.348657
# [342]	valid_0's binary_logloss: 0.348645
# [343]	valid_0's binary_logloss: 0.348628
# [344]	valid_0's binary_logloss: 0.348615
# [345]	valid_0's binary_logloss: 0.348605
# [346]	valid_0's binary_logloss: 0.348596
# [347]	valid_0's binary_logloss: 0.348592
# [348]	valid_0's binary_logloss: 0.34858
# [349]	valid_0's binary_logloss: 0.348575
# [350]	valid_0's binary_logloss: 0.348571
# [351]	valid_0's binary_logloss: 0.348561
# [352]	valid_0's binary_logloss: 0.348551
# [353]	valid_0's binary_logloss: 0.348544
# [354]	valid_0's binary_logloss: 0.348512
# [355]	valid_0's binary_logloss: 0.348507
# [356]	valid_0's binary_logloss: 0.348496
# [357]	valid_0's binary_logloss: 0.348486
# [358]	valid_0's binary_logloss: 0.34848
# [359]	valid_0's binary_logloss: 0.34847
# [360]	valid_0's binary_logloss: 0.348458
# [361]	valid_0's binary_logloss: 0.348442
# [362]	valid_0's binary_logloss: 0.348409
# [363]	valid_0's binary_logloss: 0.348395
# [364]	valid_0's binary_logloss: 0.348377
# [365]	valid_0's binary_logloss: 0.348365
# [366]	valid_0's binary_logloss: 0.348355
# [367]	valid_0's binary_logloss: 0.348341
# [368]	valid_0's binary_logloss: 0.348327
# [369]	valid_0's binary_logloss: 0.348319
# [370]	valid_0's binary_logloss: 0.348309
# [371]	valid_0's binary_logloss: 0.348298
# [372]	valid_0's binary_logloss: 0.348287
# [373]	valid_0's binary_logloss: 0.348273
# [374]	valid_0's binary_logloss: 0.348249
# [375]	valid_0's binary_logloss: 0.348236
# [376]	valid_0's binary_logloss: 0.348227
# [377]	valid_0's binary_logloss: 0.34822
# [378]	valid_0's binary_logloss: 0.34821
# [379]	valid_0's binary_logloss: 0.348204
# [380]	valid_0's binary_logloss: 0.348191
# [381]	valid_0's binary_logloss: 0.348178
# [382]	valid_0's binary_logloss: 0.348145
# [383]	valid_0's binary_logloss: 0.348131
# [384]	valid_0's binary_logloss: 0.34811
# [385]	valid_0's binary_logloss: 0.348102
# [386]	valid_0's binary_logloss: 0.348095
# [387]	valid_0's binary_logloss: 0.348087
# [388]	valid_0's binary_logloss: 0.348078
# [389]	valid_0's binary_logloss: 0.348069
# [390]	valid_0's binary_logloss: 0.348049
# [391]	valid_0's binary_logloss: 0.34803
# [392]	valid_0's binary_logloss: 0.348011
# [393]	valid_0's binary_logloss: 0.347997
# [394]	valid_0's binary_logloss: 0.347983
# [395]	valid_0's binary_logloss: 0.347968
# [396]	valid_0's binary_logloss: 0.34796
# [397]	valid_0's binary_logloss: 0.347948
# [398]	valid_0's binary_logloss: 0.347943
# [399]	valid_0's binary_logloss: 0.347925
# [400]	valid_0's binary_logloss: 0.347917
# [401]	valid_0's binary_logloss: 0.347897
# [402]	valid_0's binary_logloss: 0.34788
# [403]	valid_0's binary_logloss: 0.347868
# [404]	valid_0's binary_logloss: 0.347852
# [405]	valid_0's binary_logloss: 0.347838
# [406]	valid_0's binary_logloss: 0.347825
# [407]	valid_0's binary_logloss: 0.347818
# [408]	valid_0's binary_logloss: 0.347811
# [409]	valid_0's binary_logloss: 0.347795
# [410]	valid_0's binary_logloss: 0.347783
# [411]	valid_0's binary_logloss: 0.347764
# [412]	valid_0's binary_logloss: 0.347751
# [413]	valid_0's binary_logloss: 0.347738
# [414]	valid_0's binary_logloss: 0.347733
# [415]	valid_0's binary_logloss: 0.347724
# [416]	valid_0's binary_logloss: 0.347715
# [417]	valid_0's binary_logloss: 0.347708
# [418]	valid_0's binary_logloss: 0.347698
# [419]	valid_0's binary_logloss: 0.347692
# [420]	valid_0's binary_logloss: 0.347686
# [421]	valid_0's binary_logloss: 0.34767
# [422]	valid_0's binary_logloss: 0.347655
# [423]	valid_0's binary_logloss: 0.347643
# [424]	valid_0's binary_logloss: 0.347642
# [425]	valid_0's binary_logloss: 0.34764
# [426]	valid_0's binary_logloss: 0.347627
# [427]	valid_0's binary_logloss: 0.347609
# [428]	valid_0's binary_logloss: 0.347594
# [429]	valid_0's binary_logloss: 0.347588
# [430]	valid_0's binary_logloss: 0.347583
# [431]	valid_0's binary_logloss: 0.347574
# [432]	valid_0's binary_logloss: 0.347565
# [433]	valid_0's binary_logloss: 0.34756
# [434]	valid_0's binary_logloss: 0.347554
# [435]	valid_0's binary_logloss: 0.347545
# [436]	valid_0's binary_logloss: 0.34754
# [437]	valid_0's binary_logloss: 0.347533
# [438]	valid_0's binary_logloss: 0.347525
# [439]	valid_0's binary_logloss: 0.347516
# [440]	valid_0's binary_logloss: 0.347509
# [441]	valid_0's binary_logloss: 0.347497
# [442]	valid_0's binary_logloss: 0.347483
# [443]	valid_0's binary_logloss: 0.347476
# [444]	valid_0's binary_logloss: 0.347466
# [445]	valid_0's binary_logloss: 0.347456
# [446]	valid_0's binary_logloss: 0.347449
# [447]	valid_0's binary_logloss: 0.347437
# [448]	valid_0's binary_logloss: 0.347435
# [449]	valid_0's binary_logloss: 0.347425
# [450]	valid_0's binary_logloss: 0.34741
# [451]	valid_0's binary_logloss: 0.347395
# [452]	valid_0's binary_logloss: 0.347387
# [453]	valid_0's binary_logloss: 0.347375
# [454]	valid_0's binary_logloss: 0.347361
# [455]	valid_0's binary_logloss: 0.347349
# [456]	valid_0's binary_logloss: 0.347334
# [457]	valid_0's binary_logloss: 0.347315
# [458]	valid_0's binary_logloss: 0.347301
# [459]	valid_0's binary_logloss: 0.347287
# [460]	valid_0's binary_logloss: 0.34728
# [461]	valid_0's binary_logloss: 0.34727
# [462]	valid_0's binary_logloss: 0.347258
# [463]	valid_0's binary_logloss: 0.347243
# [464]	valid_0's binary_logloss: 0.34722
# [465]	valid_0's binary_logloss: 0.34721
# [466]	valid_0's binary_logloss: 0.347199
# [467]	valid_0's binary_logloss: 0.347193
# [468]	valid_0's binary_logloss: 0.347185
# [469]	valid_0's binary_logloss: 0.347168
# [470]	valid_0's binary_logloss: 0.347159
# [471]	valid_0's binary_logloss: 0.347151
# [472]	valid_0's binary_logloss: 0.347133
# [473]	valid_0's binary_logloss: 0.347115
# [474]	valid_0's binary_logloss: 0.347106
# [475]	valid_0's binary_logloss: 0.347086
# [476]	valid_0's binary_logloss: 0.347066
# [477]	valid_0's binary_logloss: 0.347048
# [478]	valid_0's binary_logloss: 0.34704
# [479]	valid_0's binary_logloss: 0.347025
# [480]	valid_0's binary_logloss: 0.347009
# [481]	valid_0's binary_logloss: 0.346995
# [482]	valid_0's binary_logloss: 0.346987
# [483]	valid_0's binary_logloss: 0.346969
# [484]	valid_0's binary_logloss: 0.346962
# [485]	valid_0's binary_logloss: 0.346947
# [486]	valid_0's binary_logloss: 0.346938
# [487]	valid_0's binary_logloss: 0.346932
# [488]	valid_0's binary_logloss: 0.346927
# [489]	valid_0's binary_logloss: 0.34692
# [490]	valid_0's binary_logloss: 0.346918
# [491]	valid_0's binary_logloss: 0.346911
# [492]	valid_0's binary_logloss: 0.346907
# [493]	valid_0's binary_logloss: 0.346902
# [494]	valid_0's binary_logloss: 0.346896
# [495]	valid_0's binary_logloss: 0.346893
# [496]	valid_0's binary_logloss: 0.346881
# [497]	valid_0's binary_logloss: 0.346875
# [498]	valid_0's binary_logloss: 0.34687
# [499]	valid_0's binary_logloss: 0.346859
# [500]	valid_0's binary_logloss: 0.346852
# [501]	valid_0's binary_logloss: 0.346848
# [502]	valid_0's binary_logloss: 0.346841
# [503]	valid_0's binary_logloss: 0.346839
# [504]	valid_0's binary_logloss: 0.346833
# [505]	valid_0's binary_logloss: 0.34682
# [506]	valid_0's binary_logloss: 0.346806
# [507]	valid_0's binary_logloss: 0.346796
# [508]	valid_0's binary_logloss: 0.346781
# [509]	valid_0's binary_logloss: 0.346777
# [510]	valid_0's binary_logloss: 0.346769
# [511]	valid_0's binary_logloss: 0.346764
# [512]	valid_0's binary_logloss: 0.346757
# [513]	valid_0's binary_logloss: 0.346744
# [514]	valid_0's binary_logloss: 0.346734
# [515]	valid_0's binary_logloss: 0.346728
# [516]	valid_0's binary_logloss: 0.34672
# [517]	valid_0's binary_logloss: 0.346708
# [518]	valid_0's binary_logloss: 0.346699
# [519]	valid_0's binary_logloss: 0.346692
# [520]	valid_0's binary_logloss: 0.346686
# [521]	valid_0's binary_logloss: 0.346683
# [522]	valid_0's binary_logloss: 0.346677
# [523]	valid_0's binary_logloss: 0.346674
# [524]	valid_0's binary_logloss: 0.346663
# [525]	valid_0's binary_logloss: 0.346655
# [526]	valid_0's binary_logloss: 0.346644
# [527]	valid_0's binary_logloss: 0.346635
# [528]	valid_0's binary_logloss: 0.346624
# [529]	valid_0's binary_logloss: 0.346616
# [530]	valid_0's binary_logloss: 0.346609
# [531]	valid_0's binary_logloss: 0.346602
# [532]	valid_0's binary_logloss: 0.346594
# [533]	valid_0's binary_logloss: 0.346587
# [534]	valid_0's binary_logloss: 0.346581
# [535]	valid_0's binary_logloss: 0.346577
# [536]	valid_0's binary_logloss: 0.346569
# [537]	valid_0's binary_logloss: 0.346568
# [538]	valid_0's binary_logloss: 0.346563
# [539]	valid_0's binary_logloss: 0.346556
# [540]	valid_0's binary_logloss: 0.346554
# [541]	valid_0's binary_logloss: 0.346546
# [542]	valid_0's binary_logloss: 0.346539
# [543]	valid_0's binary_logloss: 0.346521
# [544]	valid_0's binary_logloss: 0.346503
# [545]	valid_0's binary_logloss: 0.346489
# [546]	valid_0's binary_logloss: 0.346486
# [547]	valid_0's binary_logloss: 0.346482
# [548]	valid_0's binary_logloss: 0.346477
# [549]	valid_0's binary_logloss: 0.346473
# [550]	valid_0's binary_logloss: 0.346465
# [551]	valid_0's binary_logloss: 0.34646
# [552]	valid_0's binary_logloss: 0.346452
# [553]	valid_0's binary_logloss: 0.346447
# [554]	valid_0's binary_logloss: 0.346443
# [555]	valid_0's binary_logloss: 0.34644
# [556]	valid_0's binary_logloss: 0.346433
# [557]	valid_0's binary_logloss: 0.346423
# [558]	valid_0's binary_logloss: 0.346415
# [559]	valid_0's binary_logloss: 0.346409
# [560]	valid_0's binary_logloss: 0.346405
# [561]	valid_0's binary_logloss: 0.346397
# [562]	valid_0's binary_logloss: 0.346393
# [563]	valid_0's binary_logloss: 0.346386
# [564]	valid_0's binary_logloss: 0.346382
# [565]	valid_0's binary_logloss: 0.346378
# [566]	valid_0's binary_logloss: 0.346367
# [567]	valid_0's binary_logloss: 0.346359
# [568]	valid_0's binary_logloss: 0.346348
# [569]	valid_0's binary_logloss: 0.346335
# [570]	valid_0's binary_logloss: 0.346328
# [571]	valid_0's binary_logloss: 0.346325
# [572]	valid_0's binary_logloss: 0.346324
# [573]	valid_0's binary_logloss: 0.346317
# [574]	valid_0's binary_logloss: 0.346315
# [575]	valid_0's binary_logloss: 0.346306
# [576]	valid_0's binary_logloss: 0.346284
# [577]	valid_0's binary_logloss: 0.346264
# [578]	valid_0's binary_logloss: 0.346261
# [579]	valid_0's binary_logloss: 0.34625
# [580]	valid_0's binary_logloss: 0.346244
# [581]	valid_0's binary_logloss: 0.346237
# [582]	valid_0's binary_logloss: 0.346228
# [583]	valid_0's binary_logloss: 0.346219
# [584]	valid_0's binary_logloss: 0.346211
# [585]	valid_0's binary_logloss: 0.346203
# [586]	valid_0's binary_logloss: 0.346195
# [587]	valid_0's binary_logloss: 0.346184
# [588]	valid_0's binary_logloss: 0.346175
# [589]	valid_0's binary_logloss: 0.346168
# [590]	valid_0's binary_logloss: 0.346164
# [591]	valid_0's binary_logloss: 0.346161
# [592]	valid_0's binary_logloss: 0.346154
# [593]	valid_0's binary_logloss: 0.346149
# [594]	valid_0's binary_logloss: 0.346144
# [595]	valid_0's binary_logloss: 0.346139
# [596]	valid_0's binary_logloss: 0.346131
# [597]	valid_0's binary_logloss: 0.346121
# [598]	valid_0's binary_logloss: 0.346112
# [599]	valid_0's binary_logloss: 0.346101
# [600]	valid_0's binary_logloss: 0.346092
# [601]	valid_0's binary_logloss: 0.346088
# [602]	valid_0's binary_logloss: 0.346079
# [603]	valid_0's binary_logloss: 0.346075
# [604]	valid_0's binary_logloss: 0.346057
# [605]	valid_0's binary_logloss: 0.346052
# [606]	valid_0's binary_logloss: 0.346047
# [607]	valid_0's binary_logloss: 0.346043
# [608]	valid_0's binary_logloss: 0.346034
# [609]	valid_0's binary_logloss: 0.346029
# [610]	valid_0's binary_logloss: 0.346026
# [611]	valid_0's binary_logloss: 0.346009
# [612]	valid_0's binary_logloss: 0.345998
# [613]	valid_0's binary_logloss: 0.345984
# [614]	valid_0's binary_logloss: 0.345971
# [615]	valid_0's binary_logloss: 0.34596
# [616]	valid_0's binary_logloss: 0.345946
# [617]	valid_0's binary_logloss: 0.345937
# [618]	valid_0's binary_logloss: 0.345925
# [619]	valid_0's binary_logloss: 0.345913
# [620]	valid_0's binary_logloss: 0.345911
# [621]	valid_0's binary_logloss: 0.345902
# [622]	valid_0's binary_logloss: 0.345895
# [623]	valid_0's binary_logloss: 0.345892
# [624]	valid_0's binary_logloss: 0.345889
# [625]	valid_0's binary_logloss: 0.345884
# [626]	valid_0's binary_logloss: 0.345868
# [627]	valid_0's binary_logloss: 0.34586
# [628]	valid_0's binary_logloss: 0.345843
# [629]	valid_0's binary_logloss: 0.345833
# [630]	valid_0's binary_logloss: 0.345829
# [631]	valid_0's binary_logloss: 0.345816
# [632]	valid_0's binary_logloss: 0.345803
# [633]	valid_0's binary_logloss: 0.345795
# [634]	valid_0's binary_logloss: 0.345781
# [635]	valid_0's binary_logloss: 0.345769
# [636]	valid_0's binary_logloss: 0.34576
# [637]	valid_0's binary_logloss: 0.345755
# [638]	valid_0's binary_logloss: 0.345744
# [639]	valid_0's binary_logloss: 0.345736
# [640]	valid_0's binary_logloss: 0.345726
# [641]	valid_0's binary_logloss: 0.345715
# [642]	valid_0's binary_logloss: 0.345707
# [643]	valid_0's binary_logloss: 0.345701
# [644]	valid_0's binary_logloss: 0.345699
# [645]	valid_0's binary_logloss: 0.345689
# [646]	valid_0's binary_logloss: 0.345684
# [647]	valid_0's binary_logloss: 0.345679
# [648]	valid_0's binary_logloss: 0.345675
# [649]	valid_0's binary_logloss: 0.345671
# [650]	valid_0's binary_logloss: 0.345652
# [651]	valid_0's binary_logloss: 0.345646
# [652]	valid_0's binary_logloss: 0.34564
# [653]	valid_0's binary_logloss: 0.345635
# [654]	valid_0's binary_logloss: 0.345628
# [655]	valid_0's binary_logloss: 0.345625
# [656]	valid_0's binary_logloss: 0.345619
# [657]	valid_0's binary_logloss: 0.345614
# [658]	valid_0's binary_logloss: 0.345608
# [659]	valid_0's binary_logloss: 0.345604
# [660]	valid_0's binary_logloss: 0.345596
# [661]	valid_0's binary_logloss: 0.345581
# [662]	valid_0's binary_logloss: 0.345572
# [663]	valid_0's binary_logloss: 0.345559
# [664]	valid_0's binary_logloss: 0.345549
# [665]	valid_0's binary_logloss: 0.345538
# [666]	valid_0's binary_logloss: 0.345532
# [667]	valid_0's binary_logloss: 0.345526
# [668]	valid_0's binary_logloss: 0.345521
# [669]	valid_0's binary_logloss: 0.345515
# [670]	valid_0's binary_logloss: 0.345512
# [671]	valid_0's binary_logloss: 0.345506
# [672]	valid_0's binary_logloss: 0.345496
# [673]	valid_0's binary_logloss: 0.345482
# [674]	valid_0's binary_logloss: 0.345477
# [675]	valid_0's binary_logloss: 0.345469
# [676]	valid_0's binary_logloss: 0.345458
# [677]	valid_0's binary_logloss: 0.345445
# [678]	valid_0's binary_logloss: 0.345437
# [679]	valid_0's binary_logloss: 0.345433
# [680]	valid_0's binary_logloss: 0.345424
# [681]	valid_0's binary_logloss: 0.345423
# [682]	valid_0's binary_logloss: 0.34542
# [683]	valid_0's binary_logloss: 0.345421
# [684]	valid_0's binary_logloss: 0.34542
# [685]	valid_0's binary_logloss: 0.345418
# [686]	valid_0's binary_logloss: 0.345409
# [687]	valid_0's binary_logloss: 0.345407
# [688]	valid_0's binary_logloss: 0.345401
# [689]	valid_0's binary_logloss: 0.345393
# [690]	valid_0's binary_logloss: 0.345385
# [691]	valid_0's binary_logloss: 0.345376
# [692]	valid_0's binary_logloss: 0.345368
# [693]	valid_0's binary_logloss: 0.34535
# [694]	valid_0's binary_logloss: 0.345346
# [695]	valid_0's binary_logloss: 0.34534
# [696]	valid_0's binary_logloss: 0.345335
# [697]	valid_0's binary_logloss: 0.345333
# [698]	valid_0's binary_logloss: 0.345331
# [699]	valid_0's binary_logloss: 0.345328
# [700]	valid_0's binary_logloss: 0.345325
# [701]	valid_0's binary_logloss: 0.345315
# [702]	valid_0's binary_logloss: 0.345311
# [703]	valid_0's binary_logloss: 0.345304
# [704]	valid_0's binary_logloss: 0.345304
# [705]	valid_0's binary_logloss: 0.345295
# [706]	valid_0's binary_logloss: 0.345287
# [707]	valid_0's binary_logloss: 0.345272
# [708]	valid_0's binary_logloss: 0.345263
# [709]	valid_0's binary_logloss: 0.34525
# [710]	valid_0's binary_logloss: 0.345245
# [711]	valid_0's binary_logloss: 0.345236
# [712]	valid_0's binary_logloss: 0.345221
# [713]	valid_0's binary_logloss: 0.345214
# [714]	valid_0's binary_logloss: 0.345211
# [715]	valid_0's binary_logloss: 0.345208
# [716]	valid_0's binary_logloss: 0.345201
# [717]	valid_0's binary_logloss: 0.345196
# [718]	valid_0's binary_logloss: 0.345192
# [719]	valid_0's binary_logloss: 0.345189
# [720]	valid_0's binary_logloss: 0.34518
# [721]	valid_0's binary_logloss: 0.345174
# [722]	valid_0's binary_logloss: 0.345169
# [723]	valid_0's binary_logloss: 0.345163
# [724]	valid_0's binary_logloss: 0.345158
# [725]	valid_0's binary_logloss: 0.345156
# [726]	valid_0's binary_logloss: 0.34515
# [727]	valid_0's binary_logloss: 0.345144
# [728]	valid_0's binary_logloss: 0.345135
# [729]	valid_0's binary_logloss: 0.345134
# [730]	valid_0's binary_logloss: 0.34513
# [731]	valid_0's binary_logloss: 0.345121
# [732]	valid_0's binary_logloss: 0.345116
# [733]	valid_0's binary_logloss: 0.345109
# [734]	valid_0's binary_logloss: 0.345107
# [735]	valid_0's binary_logloss: 0.345104
# [736]	valid_0's binary_logloss: 0.345094
# [737]	valid_0's binary_logloss: 0.345087
# [738]	valid_0's binary_logloss: 0.345082
# [739]	valid_0's binary_logloss: 0.345076
# [740]	valid_0's binary_logloss: 0.345072
# [741]	valid_0's binary_logloss: 0.345068
# [742]	valid_0's binary_logloss: 0.345061
# [743]	valid_0's binary_logloss: 0.345056
# [744]	valid_0's binary_logloss: 0.345049
# [745]	valid_0's binary_logloss: 0.345044
# [746]	valid_0's binary_logloss: 0.34504
# [747]	valid_0's binary_logloss: 0.345038
# [748]	valid_0's binary_logloss: 0.345032
# [749]	valid_0's binary_logloss: 0.345026
# [750]	valid_0's binary_logloss: 0.345024
# [751]	valid_0's binary_logloss: 0.345018
# [752]	valid_0's binary_logloss: 0.345015
# [753]	valid_0's binary_logloss: 0.345012
# [754]	valid_0's binary_logloss: 0.345006
# [755]	valid_0's binary_logloss: 0.344995
# [756]	valid_0's binary_logloss: 0.344989
# [757]	valid_0's binary_logloss: 0.344985
# [758]	valid_0's binary_logloss: 0.344972
# [759]	valid_0's binary_logloss: 0.344969
# [760]	valid_0's binary_logloss: 0.344965
# [761]	valid_0's binary_logloss: 0.344961
# [762]	valid_0's binary_logloss: 0.344957
# [763]	valid_0's binary_logloss: 0.344947
# [764]	valid_0's binary_logloss: 0.344945
# [765]	valid_0's binary_logloss: 0.344937
# [766]	valid_0's binary_logloss: 0.344932
# [767]	valid_0's binary_logloss: 0.344927
# [768]	valid_0's binary_logloss: 0.344917
# [769]	valid_0's binary_logloss: 0.34491
# [770]	valid_0's binary_logloss: 0.3449
# [771]	valid_0's binary_logloss: 0.344891
# [772]	valid_0's binary_logloss: 0.344885
# [773]	valid_0's binary_logloss: 0.344877
# [774]	valid_0's binary_logloss: 0.344867
# [775]	valid_0's binary_logloss: 0.344857
# [776]	valid_0's binary_logloss: 0.344855
# [777]	valid_0's binary_logloss: 0.344844
# [778]	valid_0's binary_logloss: 0.344837
# [779]	valid_0's binary_logloss: 0.344829
# [780]	valid_0's binary_logloss: 0.344826
# [781]	valid_0's binary_logloss: 0.344824
# [782]	valid_0's binary_logloss: 0.344824
# [783]	valid_0's binary_logloss: 0.344817
# [784]	valid_0's binary_logloss: 0.344811
# [785]	valid_0's binary_logloss: 0.344809
# [786]	valid_0's binary_logloss: 0.344799
# [787]	valid_0's binary_logloss: 0.344785
# [788]	valid_0's binary_logloss: 0.344779
# [789]	valid_0's binary_logloss: 0.344775
# [790]	valid_0's binary_logloss: 0.34477
# [791]	valid_0's binary_logloss: 0.344768
# [792]	valid_0's binary_logloss: 0.344753
# [793]	valid_0's binary_logloss: 0.344747
# [794]	valid_0's binary_logloss: 0.344741
# [795]	valid_0's binary_logloss: 0.344729
# [796]	valid_0's binary_logloss: 0.344725
# [797]	valid_0's binary_logloss: 0.344724
# [798]	valid_0's binary_logloss: 0.344716
# [799]	valid_0's binary_logloss: 0.344716
# [800]	valid_0's binary_logloss: 0.344717
# [801]	valid_0's binary_logloss: 0.344713
# [802]	valid_0's binary_logloss: 0.344704
# [803]	valid_0's binary_logloss: 0.344703
# [804]	valid_0's binary_logloss: 0.344694
# [805]	valid_0's binary_logloss: 0.344686
# [806]	valid_0's binary_logloss: 0.344682
# [807]	valid_0's binary_logloss: 0.344678
# [808]	valid_0's binary_logloss: 0.34467
# [809]	valid_0's binary_logloss: 0.344663
# [810]	valid_0's binary_logloss: 0.344651
# [811]	valid_0's binary_logloss: 0.344643
# [812]	valid_0's binary_logloss: 0.344637
# [813]	valid_0's binary_logloss: 0.344634
# [814]	valid_0's binary_logloss: 0.344628
# [815]	valid_0's binary_logloss: 0.344623
# [816]	valid_0's binary_logloss: 0.344621
# [817]	valid_0's binary_logloss: 0.344615
# [818]	valid_0's binary_logloss: 0.344615
# [819]	valid_0's binary_logloss: 0.344609
# [820]	valid_0's binary_logloss: 0.344597
# [821]	valid_0's binary_logloss: 0.344593
# [822]	valid_0's binary_logloss: 0.344588
# [823]	valid_0's binary_logloss: 0.344584
# [824]	valid_0's binary_logloss: 0.344577
# [825]	valid_0's binary_logloss: 0.344574
# [826]	valid_0's binary_logloss: 0.344567
# [827]	valid_0's binary_logloss: 0.34456
# [828]	valid_0's binary_logloss: 0.344552
# [829]	valid_0's binary_logloss: 0.344546
# [830]	valid_0's binary_logloss: 0.344537
# [831]	valid_0's binary_logloss: 0.344534
# [832]	valid_0's binary_logloss: 0.344524
# [833]	valid_0's binary_logloss: 0.34452
# [834]	valid_0's binary_logloss: 0.344517
# [835]	valid_0's binary_logloss: 0.344513
# [836]	valid_0's binary_logloss: 0.344505
# [837]	valid_0's binary_logloss: 0.344505
# [838]	valid_0's binary_logloss: 0.344494
# [839]	valid_0's binary_logloss: 0.344492
# [840]	valid_0's binary_logloss: 0.344483
# [841]	valid_0's binary_logloss: 0.344478
# [842]	valid_0's binary_logloss: 0.344475
# [843]	valid_0's binary_logloss: 0.34447
# [844]	valid_0's binary_logloss: 0.344466
# [845]	valid_0's binary_logloss: 0.344463
# [846]	valid_0's binary_logloss: 0.344455
# [847]	valid_0's binary_logloss: 0.344453
# [848]	valid_0's binary_logloss: 0.34445
# [849]	valid_0's binary_logloss: 0.344442
# [850]	valid_0's binary_logloss: 0.344439
# [851]	valid_0's binary_logloss: 0.344434
# [852]	valid_0's binary_logloss: 0.344433
# [853]	valid_0's binary_logloss: 0.34443
# [854]	valid_0's binary_logloss: 0.344424
# [855]	valid_0's binary_logloss: 0.34442
# [856]	valid_0's binary_logloss: 0.344411
# [857]	valid_0's binary_logloss: 0.344401
# [858]	valid_0's binary_logloss: 0.344394
# [859]	valid_0's binary_logloss: 0.344387
# [860]	valid_0's binary_logloss: 0.344381
# [861]	valid_0's binary_logloss: 0.344372
# [862]	valid_0's binary_logloss: 0.344368
# [863]	valid_0's binary_logloss: 0.344358
# [864]	valid_0's binary_logloss: 0.344355
# [865]	valid_0's binary_logloss: 0.344354
# [866]	valid_0's binary_logloss: 0.34435
# [867]	valid_0's binary_logloss: 0.344345
# [868]	valid_0's binary_logloss: 0.344335
# [869]	valid_0's binary_logloss: 0.344323
# [870]	valid_0's binary_logloss: 0.344318
# [871]	valid_0's binary_logloss: 0.344317
# [872]	valid_0's binary_logloss: 0.344316
# [873]	valid_0's binary_logloss: 0.344306
# [874]	valid_0's binary_logloss: 0.344303
# [875]	valid_0's binary_logloss: 0.344297
# [876]	valid_0's binary_logloss: 0.344292
# [877]	valid_0's binary_logloss: 0.344287
# [878]	valid_0's binary_logloss: 0.34428
# [879]	valid_0's binary_logloss: 0.344273
# [880]	valid_0's binary_logloss: 0.344274
# [881]	valid_0's binary_logloss: 0.344274
# [882]	valid_0's binary_logloss: 0.344267
# [883]	valid_0's binary_logloss: 0.344266
# [884]	valid_0's binary_logloss: 0.344261
# [885]	valid_0's binary_logloss: 0.344259
# [886]	valid_0's binary_logloss: 0.344254
# [887]	valid_0's binary_logloss: 0.344249
# [888]	valid_0's binary_logloss: 0.344243
# [889]	valid_0's binary_logloss: 0.344238
# [890]	valid_0's binary_logloss: 0.344233
# [891]	valid_0's binary_logloss: 0.344227
# [892]	valid_0's binary_logloss: 0.344221
# [893]	valid_0's binary_logloss: 0.344216
# [894]	valid_0's binary_logloss: 0.344214
# [895]	valid_0's binary_logloss: 0.34421
# [896]	valid_0's binary_logloss: 0.344207
# [897]	valid_0's binary_logloss: 0.344203
# [898]	valid_0's binary_logloss: 0.3442
# [899]	valid_0's binary_logloss: 0.344192
# [900]	valid_0's binary_logloss: 0.344186
# [901]	valid_0's binary_logloss: 0.344175
# [902]	valid_0's binary_logloss: 0.344169
# [903]	valid_0's binary_logloss: 0.344158
# [904]	valid_0's binary_logloss: 0.344154
# [905]	valid_0's binary_logloss: 0.344148
# [906]	valid_0's binary_logloss: 0.344143
# [907]	valid_0's binary_logloss: 0.344138
# [908]	valid_0's binary_logloss: 0.34413
# [909]	valid_0's binary_logloss: 0.344125
# [910]	valid_0's binary_logloss: 0.344119
# [911]	valid_0's binary_logloss: 0.34411
# [912]	valid_0's binary_logloss: 0.344101
# [913]	valid_0's binary_logloss: 0.344095
# [914]	valid_0's binary_logloss: 0.344087
# [915]	valid_0's binary_logloss: 0.344081
# [916]	valid_0's binary_logloss: 0.344076
# [917]	valid_0's binary_logloss: 0.344074
# [918]	valid_0's binary_logloss: 0.344067
# [919]	valid_0's binary_logloss: 0.34406
# [920]	valid_0's binary_logloss: 0.344059
# [921]	valid_0's binary_logloss: 0.344048
# [922]	valid_0's binary_logloss: 0.344043
# [923]	valid_0's binary_logloss: 0.344036
# [924]	valid_0's binary_logloss: 0.344035
# [925]	valid_0's binary_logloss: 0.344026
# [926]	valid_0's binary_logloss: 0.344018
# [927]	valid_0's binary_logloss: 0.344014
# [928]	valid_0's binary_logloss: 0.344005
# [929]	valid_0's binary_logloss: 0.343998
# [930]	valid_0's binary_logloss: 0.343992
# [931]	valid_0's binary_logloss: 0.343986
# [932]	valid_0's binary_logloss: 0.343975
# [933]	valid_0's binary_logloss: 0.343969
# [934]	valid_0's binary_logloss: 0.343958
# [935]	valid_0's binary_logloss: 0.343956
# [936]	valid_0's binary_logloss: 0.343951
# [937]	valid_0's binary_logloss: 0.343944
# [938]	valid_0's binary_logloss: 0.343936
# [939]	valid_0's binary_logloss: 0.343931
# [940]	valid_0's binary_logloss: 0.343927
# [941]	valid_0's binary_logloss: 0.343921
# [942]	valid_0's binary_logloss: 0.343913
# [943]	valid_0's binary_logloss: 0.343907
# [944]	valid_0's binary_logloss: 0.343896
# [945]	valid_0's binary_logloss: 0.34389
# [946]	valid_0's binary_logloss: 0.343875
# [947]	valid_0's binary_logloss: 0.343871
# [948]	valid_0's binary_logloss: 0.343872
# [949]	valid_0's binary_logloss: 0.343872
# [950]	valid_0's binary_logloss: 0.343866
# [951]	valid_0's binary_logloss: 0.343859
# [952]	valid_0's binary_logloss: 0.343856
# [953]	valid_0's binary_logloss: 0.343853
# [954]	valid_0's binary_logloss: 0.343849
# [955]	valid_0's binary_logloss: 0.343842
# [956]	valid_0's binary_logloss: 0.343829
# [957]	valid_0's binary_logloss: 0.343812
# [958]	valid_0's binary_logloss: 0.343798
# [959]	valid_0's binary_logloss: 0.343792
# [960]	valid_0's binary_logloss: 0.343788
# [961]	valid_0's binary_logloss: 0.343782
# [962]	valid_0's binary_logloss: 0.34378
# [963]	valid_0's binary_logloss: 0.343776
# [964]	valid_0's binary_logloss: 0.343773
# [965]	valid_0's binary_logloss: 0.343758
# [966]	valid_0's binary_logloss: 0.343751
# [967]	valid_0's binary_logloss: 0.343749
# [968]	valid_0's binary_logloss: 0.343748
# [969]	valid_0's binary_logloss: 0.343744
# [970]	valid_0's binary_logloss: 0.343734
# [971]	valid_0's binary_logloss: 0.343726
# [972]	valid_0's binary_logloss: 0.343721
# [973]	valid_0's binary_logloss: 0.343709
# [974]	valid_0's binary_logloss: 0.343701
# [975]	valid_0's binary_logloss: 0.343697
# [976]	valid_0's binary_logloss: 0.343691
# [977]	valid_0's binary_logloss: 0.343684
# [978]	valid_0's binary_logloss: 0.343678
# [979]	valid_0's binary_logloss: 0.343674
# [980]	valid_0's binary_logloss: 0.343671
# [981]	valid_0's binary_logloss: 0.343668
# [982]	valid_0's binary_logloss: 0.343665
# [983]	valid_0's binary_logloss: 0.343663
# [984]	valid_0's binary_logloss: 0.343661
# [985]	valid_0's binary_logloss: 0.343658
# [986]	valid_0's binary_logloss: 0.343648
# [987]	valid_0's binary_logloss: 0.343635
# [988]	valid_0's binary_logloss: 0.343627
# [989]	valid_0's binary_logloss: 0.343618
# [990]	valid_0's binary_logloss: 0.343605
# [991]	valid_0's binary_logloss: 0.343601
# [992]	valid_0's binary_logloss: 0.343598
# [993]	valid_0's binary_logloss: 0.343595
# [994]	valid_0's binary_logloss: 0.343591
# [995]	valid_0's binary_logloss: 0.343586
# [996]	valid_0's binary_logloss: 0.343576
# [997]	valid_0's binary_logloss: 0.343563
# [998]	valid_0's binary_logloss: 0.343558
# [999]	valid_0's binary_logloss: 0.343548
# [1000]	valid_0's binary_logloss: 0.343544
# [1001]	valid_0's binary_logloss: 0.343533
# [1002]	valid_0's binary_logloss: 0.343527
# [1003]	valid_0's binary_logloss: 0.343522
# [1004]	valid_0's binary_logloss: 0.343514
# [1005]	valid_0's binary_logloss: 0.343511
# [1006]	valid_0's binary_logloss: 0.343507
# [1007]	valid_0's binary_logloss: 0.343503
# [1008]	valid_0's binary_logloss: 0.343501
# [1009]	valid_0's binary_logloss: 0.343495
# [1010]	valid_0's binary_logloss: 0.343489
# [1011]	valid_0's binary_logloss: 0.343485
# [1012]	valid_0's binary_logloss: 0.34348
# [1013]	valid_0's binary_logloss: 0.343475
# [1014]	valid_0's binary_logloss: 0.343473
# [1015]	valid_0's binary_logloss: 0.343471
# [1016]	valid_0's binary_logloss: 0.343465
# [1017]	valid_0's binary_logloss: 0.343454
# [1018]	valid_0's binary_logloss: 0.343445
# [1019]	valid_0's binary_logloss: 0.34344
# [1020]	valid_0's binary_logloss: 0.343431
# [1021]	valid_0's binary_logloss: 0.34343
# [1022]	valid_0's binary_logloss: 0.34343
# [1023]	valid_0's binary_logloss: 0.343426
# [1024]	valid_0's binary_logloss: 0.343429
# [1025]	valid_0's binary_logloss: 0.343426
# [1026]	valid_0's binary_logloss: 0.343423
# [1027]	valid_0's binary_logloss: 0.343415
# [1028]	valid_0's binary_logloss: 0.343412
# [1029]	valid_0's binary_logloss: 0.343408
# [1030]	valid_0's binary_logloss: 0.343407
# [1031]	valid_0's binary_logloss: 0.343402
# [1032]	valid_0's binary_logloss: 0.3434
# [1033]	valid_0's binary_logloss: 0.343396
# [1034]	valid_0's binary_logloss: 0.343391
# [1035]	valid_0's binary_logloss: 0.343391
# [1036]	valid_0's binary_logloss: 0.343381
# [1037]	valid_0's binary_logloss: 0.34337
# [1038]	valid_0's binary_logloss: 0.343363
# [1039]	valid_0's binary_logloss: 0.343358
# [1040]	valid_0's binary_logloss: 0.343353
# [1041]	valid_0's binary_logloss: 0.34335
# [1042]	valid_0's binary_logloss: 0.343347
# [1043]	valid_0's binary_logloss: 0.343345
# [1044]	valid_0's binary_logloss: 0.343339
# [1045]	valid_0's binary_logloss: 0.343333
# [1046]	valid_0's binary_logloss: 0.343325
# [1047]	valid_0's binary_logloss: 0.343319
# [1048]	valid_0's binary_logloss: 0.34331
# [1049]	valid_0's binary_logloss: 0.343304
# [1050]	valid_0's binary_logloss: 0.3433
# [1051]	valid_0's binary_logloss: 0.343291
# [1052]	valid_0's binary_logloss: 0.343289
# [1053]	valid_0's binary_logloss: 0.343287
# [1054]	valid_0's binary_logloss: 0.343287
# [1055]	valid_0's binary_logloss: 0.343284
# [1056]	valid_0's binary_logloss: 0.343281
# [1057]	valid_0's binary_logloss: 0.343274
# [1058]	valid_0's binary_logloss: 0.343275
# [1059]	valid_0's binary_logloss: 0.343273
# [1060]	valid_0's binary_logloss: 0.34327
# [1061]	valid_0's binary_logloss: 0.343264
# [1062]	valid_0's binary_logloss: 0.343258
# [1063]	valid_0's binary_logloss: 0.34325
# [1064]	valid_0's binary_logloss: 0.343245
# [1065]	valid_0's binary_logloss: 0.34324
# [1066]	valid_0's binary_logloss: 0.34323
# [1067]	valid_0's binary_logloss: 0.343222
# [1068]	valid_0's binary_logloss: 0.343217
# [1069]	valid_0's binary_logloss: 0.34321
# [1070]	valid_0's binary_logloss: 0.343207
# [1071]	valid_0's binary_logloss: 0.343196
# [1072]	valid_0's binary_logloss: 0.343187
# [1073]	valid_0's binary_logloss: 0.343182
# [1074]	valid_0's binary_logloss: 0.343172
# [1075]	valid_0's binary_logloss: 0.343166
# [1076]	valid_0's binary_logloss: 0.343162
# [1077]	valid_0's binary_logloss: 0.343159
# [1078]	valid_0's binary_logloss: 0.343153
# [1079]	valid_0's binary_logloss: 0.343148
# [1080]	valid_0's binary_logloss: 0.343141
# [1081]	valid_0's binary_logloss: 0.343131
# [1082]	valid_0's binary_logloss: 0.343128
# [1083]	valid_0's binary_logloss: 0.343124
# [1084]	valid_0's binary_logloss: 0.34312
# [1085]	valid_0's binary_logloss: 0.343114
# [1086]	valid_0's binary_logloss: 0.343114
# [1087]	valid_0's binary_logloss: 0.343113
# [1088]	valid_0's binary_logloss: 0.343116
# [1089]	valid_0's binary_logloss: 0.343111
# [1090]	valid_0's binary_logloss: 0.343109
# [1091]	valid_0's binary_logloss: 0.343096
# [1092]	valid_0's binary_logloss: 0.343093
# [1093]	valid_0's binary_logloss: 0.343082
# [1094]	valid_0's binary_logloss: 0.34308
# [1095]	valid_0's binary_logloss: 0.34307
# [1096]	valid_0's binary_logloss: 0.343066
# [1097]	valid_0's binary_logloss: 0.343063
# [1098]	valid_0's binary_logloss: 0.34306
# [1099]	valid_0's binary_logloss: 0.343057
# [1100]	valid_0's binary_logloss: 0.343059
# [1101]	valid_0's binary_logloss: 0.343055
# [1102]	valid_0's binary_logloss: 0.343051
# [1103]	valid_0's binary_logloss: 0.343047
# [1104]	valid_0's binary_logloss: 0.343047
# [1105]	valid_0's binary_logloss: 0.343043
# [1106]	valid_0's binary_logloss: 0.343039
# [1107]	valid_0's binary_logloss: 0.343031
# [1108]	valid_0's binary_logloss: 0.343026
# [1109]	valid_0's binary_logloss: 0.343022
# [1110]	valid_0's binary_logloss: 0.343015
# [1111]	valid_0's binary_logloss: 0.34301
# [1112]	valid_0's binary_logloss: 0.343006
# [1113]	valid_0's binary_logloss: 0.342995
# [1114]	valid_0's binary_logloss: 0.342992
# [1115]	valid_0's binary_logloss: 0.342988
# [1116]	valid_0's binary_logloss: 0.342983
# [1117]	valid_0's binary_logloss: 0.342973
# [1118]	valid_0's binary_logloss: 0.342964
# [1119]	valid_0's binary_logloss: 0.342957
# [1120]	valid_0's binary_logloss: 0.342945
# [1121]	valid_0's binary_logloss: 0.342941
# [1122]	valid_0's binary_logloss: 0.342939
# [1123]	valid_0's binary_logloss: 0.342933
# [1124]	valid_0's binary_logloss: 0.342925
# [1125]	valid_0's binary_logloss: 0.342924
# [1126]	valid_0's binary_logloss: 0.342916
# [1127]	valid_0's binary_logloss: 0.342906
# [1128]	valid_0's binary_logloss: 0.342899
# [1129]	valid_0's binary_logloss: 0.342898
# [1130]	valid_0's binary_logloss: 0.342893
# [1131]	valid_0's binary_logloss: 0.342886
# [1132]	valid_0's binary_logloss: 0.342881
# [1133]	valid_0's binary_logloss: 0.342875
# [1134]	valid_0's binary_logloss: 0.34287
# [1135]	valid_0's binary_logloss: 0.342866
# [1136]	valid_0's binary_logloss: 0.342853
# [1137]	valid_0's binary_logloss: 0.342848
# [1138]	valid_0's binary_logloss: 0.342845
# [1139]	valid_0's binary_logloss: 0.342844
# [1140]	valid_0's binary_logloss: 0.342831
# [1141]	valid_0's binary_logloss: 0.342825
# [1142]	valid_0's binary_logloss: 0.342822
# [1143]	valid_0's binary_logloss: 0.342812
# [1144]	valid_0's binary_logloss: 0.342809
# [1145]	valid_0's binary_logloss: 0.342805
# [1146]	valid_0's binary_logloss: 0.342804
# [1147]	valid_0's binary_logloss: 0.342802
# [1148]	valid_0's binary_logloss: 0.3428
# [1149]	valid_0's binary_logloss: 0.342796
# [1150]	valid_0's binary_logloss: 0.342794
# [1151]	valid_0's binary_logloss: 0.342791
# [1152]	valid_0's binary_logloss: 0.34279
# [1153]	valid_0's binary_logloss: 0.342786
# [1154]	valid_0's binary_logloss: 0.342784
# [1155]	valid_0's binary_logloss: 0.34278
# [1156]	valid_0's binary_logloss: 0.342765
# [1157]	valid_0's binary_logloss: 0.342754
# [1158]	valid_0's binary_logloss: 0.342746
# [1159]	valid_0's binary_logloss: 0.342749
# [1160]	valid_0's binary_logloss: 0.34274
# [1161]	valid_0's binary_logloss: 0.342738
# [1162]	valid_0's binary_logloss: 0.342738
# [1163]	valid_0's binary_logloss: 0.34274
# [1164]	valid_0's binary_logloss: 0.342736
# [1165]	valid_0's binary_logloss: 0.342732
# [1166]	valid_0's binary_logloss: 0.342734
# [1167]	valid_0's binary_logloss: 0.342725
# [1168]	valid_0's binary_logloss: 0.342723
# [1169]	valid_0's binary_logloss: 0.342716
# [1170]	valid_0's binary_logloss: 0.342714
# [1171]	valid_0's binary_logloss: 0.34271
# [1172]	valid_0's binary_logloss: 0.342702
# [1173]	valid_0's binary_logloss: 0.342699
# [1174]	valid_0's binary_logloss: 0.342694
# [1175]	valid_0's binary_logloss: 0.342682
# [1176]	valid_0's binary_logloss: 0.34268
# [1177]	valid_0's binary_logloss: 0.342679
# [1178]	valid_0's binary_logloss: 0.342678
# [1179]	valid_0's binary_logloss: 0.342676
# [1180]	valid_0's binary_logloss: 0.342674
# [1181]	valid_0's binary_logloss: 0.342664
# [1182]	valid_0's binary_logloss: 0.342653
# [1183]	valid_0's binary_logloss: 0.342645
# [1184]	valid_0's binary_logloss: 0.342639
# [1185]	valid_0's binary_logloss: 0.342634
# [1186]	valid_0's binary_logloss: 0.342627
# [1187]	valid_0's binary_logloss: 0.342615
# [1188]	valid_0's binary_logloss: 0.342608
# [1189]	valid_0's binary_logloss: 0.342604
# [1190]	valid_0's binary_logloss: 0.342597
# [1191]	valid_0's binary_logloss: 0.342597
# [1192]	valid_0's binary_logloss: 0.342596
# [1193]	valid_0's binary_logloss: 0.342595
# [1194]	valid_0's binary_logloss: 0.342591
# [1195]	valid_0's binary_logloss: 0.342584
# [1196]	valid_0's binary_logloss: 0.34258
# [1197]	valid_0's binary_logloss: 0.342575
# [1198]	valid_0's binary_logloss: 0.342572
# [1199]	valid_0's binary_logloss: 0.342567
# [1200]	valid_0's binary_logloss: 0.342565
# [1201]	valid_0's binary_logloss: 0.342558
# [1202]	valid_0's binary_logloss: 0.34255
# [1203]	valid_0's binary_logloss: 0.342547
# [1204]	valid_0's binary_logloss: 0.342543
# [1205]	valid_0's binary_logloss: 0.34254
# [1206]	valid_0's binary_logloss: 0.342535
# [1207]	valid_0's binary_logloss: 0.342533
# [1208]	valid_0's binary_logloss: 0.342531
# [1209]	valid_0's binary_logloss: 0.342526
# [1210]	valid_0's binary_logloss: 0.342521
# [1211]	valid_0's binary_logloss: 0.342517
# [1212]	valid_0's binary_logloss: 0.342516
# [1213]	valid_0's binary_logloss: 0.342512
# [1214]	valid_0's binary_logloss: 0.342509
# [1215]	valid_0's binary_logloss: 0.342503
# [1216]	valid_0's binary_logloss: 0.342491
# [1217]	valid_0's binary_logloss: 0.342483
# [1218]	valid_0's binary_logloss: 0.342482
# [1219]	valid_0's binary_logloss: 0.342473
# [1220]	valid_0's binary_logloss: 0.342467
# [1221]	valid_0's binary_logloss: 0.342463
# [1222]	valid_0's binary_logloss: 0.342462
# [1223]	valid_0's binary_logloss: 0.342455
# [1224]	valid_0's binary_logloss: 0.342452
# [1225]	valid_0's binary_logloss: 0.342449
# [1226]	valid_0's binary_logloss: 0.342443
# [1227]	valid_0's binary_logloss: 0.342442
# [1228]	valid_0's binary_logloss: 0.342437
# [1229]	valid_0's binary_logloss: 0.342433
# [1230]	valid_0's binary_logloss: 0.342429
# [1231]	valid_0's binary_logloss: 0.342425
# [1232]	valid_0's binary_logloss: 0.34242
# [1233]	valid_0's binary_logloss: 0.342417
# [1234]	valid_0's binary_logloss: 0.342414
# [1235]	valid_0's binary_logloss: 0.342407
# [1236]	valid_0's binary_logloss: 0.342398
# [1237]	valid_0's binary_logloss: 0.342393
# [1238]	valid_0's binary_logloss: 0.342383
# [1239]	valid_0's binary_logloss: 0.342379
# [1240]	valid_0's binary_logloss: 0.342368
# [1241]	valid_0's binary_logloss: 0.342364
# [1242]	valid_0's binary_logloss: 0.34236
# [1243]	valid_0's binary_logloss: 0.342352
# [1244]	valid_0's binary_logloss: 0.342346
# [1245]	valid_0's binary_logloss: 0.342344
# [1246]	valid_0's binary_logloss: 0.342339
# [1247]	valid_0's binary_logloss: 0.342337
# [1248]	valid_0's binary_logloss: 0.342334
# [1249]	valid_0's binary_logloss: 0.342332
# [1250]	valid_0's binary_logloss: 0.342328
# [1251]	valid_0's binary_logloss: 0.342327
# [1252]	valid_0's binary_logloss: 0.342322
# [1253]	valid_0's binary_logloss: 0.342318
# [1254]	valid_0's binary_logloss: 0.342314
# [1255]	valid_0's binary_logloss: 0.342313
# [1256]	valid_0's binary_logloss: 0.342309
# [1257]	valid_0's binary_logloss: 0.342307
# [1258]	valid_0's binary_logloss: 0.342302
# [1259]	valid_0's binary_logloss: 0.342298
# [1260]	valid_0's binary_logloss: 0.342296
# [1261]	valid_0's binary_logloss: 0.342297
# [1262]	valid_0's binary_logloss: 0.342299
# [1263]	valid_0's binary_logloss: 0.342299
# [1264]	valid_0's binary_logloss: 0.342297
# [1265]	valid_0's binary_logloss: 0.342298
# Early stopping, best iteration is:
# [1260]	valid_0's binary_logloss: 0.342296
# Done

# %%
# %%time
test = get_features(test)
test = test.fillna(-1)
print('done')
# Out:
# done
# Wall time: 50min 20s

# %%
test.to_csv('feat_test.csv', index=False)

# %%
d_test = lgb.Dataset(test[col]) #xgb.DMatrix(test[col])
p_test = gbm.predict(test[col])

sub = pd.DataFrame()
sub['test_id'] = test['test_id']
sub['is_duplicate'] = p_test

#df['is_duplicate'] = df['is_duplicate'].map(lambda x: 0.000000000001 if x < 0.0001 else x)
#df['is_duplicate'] = df['is_duplicate'].map(lambda x: 0.999999999999 if x > 0.98 else x)

sub.to_csv('gbm_test.csv', index=False)
print('done')
# Out:
# done
